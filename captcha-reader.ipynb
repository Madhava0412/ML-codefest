# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread('Data/1a1SZ.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(img, cmap='gray')
